# %%
#Import neccessary packages
import polars as pl
import pandas as pd 
import duckdb
import ibis

# %%
#Setup Connection with DuckDB
con = ibis.connect('C:/Users/Apoorva Shetty/Documents/GitHub/SummerProject/data/samhsa_data2.db')
con.list_tables() # List the tables in the db
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[6], line 2
#       1 #Setup Connection with DuckDB
# ----> 2 con = ibis.connect('C:/Users/Apoorva Shetty/Documents/GitHub/SummerProject/data/samhsa_data2.db')
#       3 con.list_tables() # List the tables in the db
#
# File c:\Users\Apoorva Shetty\miniconda3\envs\llm_env\Lib\site-packages\ibis\backends\__init__.py:1357, in connect(resource, **kwargs)
#    1355     return ibis.duckdb.connect(path, **kwargs)
#    1356 elif path.endswith((".sqlite", ".db")):
# -> 1357     return ibis.sqlite.connect(path, **kwargs)
#    1358 elif path.endswith((".parquet", ".csv", ".csv.gz")):
#    1359     # Load parquet/csv/csv.gz files with duckdb by default
#    1360     con = ibis.duckdb.connect(**kwargs)
#
# ...

# %%
raw_data.head().to_pandas()
# Out:
#    ADMYR       CASEID  STFIPS  CBSA2010  EDUC  MARSTAT  SERVICES  DETCRIM  \
# 0   2015  20151524993       2        -9     2        4         7       -9
# 1   2015  20151449532       2        -9     3        2         7        6
# 2   2015  20151431263       2        -9    -9        1         7        6
# 3   2015  20151401765       2        -9     5        2         6       -9
# 4   2015  20151461771       2        -9     3        1         7        6
#
#    NOPRIOR  PSOURCE  ...  TRNQFLG  BARBFLG  SEDHPFLG  INHFLG  OTCFLG  \
# 0        1        1  ...        0        0         0       0       0
# 1        5        7  ...        0        0         0       0       0
# 2        2        7  ...        0        0         0       0       0
# 3        0        6  ...        0        0         0       0       0
# 4        4        7  ...        0        0         0       0       0
#
#    OTHERFLG  DIVISION  REGION  IDU  ALCDRUG
# 0         0         9       4    0        1
# ...
